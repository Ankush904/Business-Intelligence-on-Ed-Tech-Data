# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('online_All_Business_p1_p626.csv')
data.head()
# Out:
#         id                                              title  \
# 0   762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1   937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2  1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
# 3   648826         The Complete Financial Analyst Course 2020
# 4   637930  An Entire MBA in 1 Course:Award Winning Busine...
#
#                                                  url  is_paid  \
# 0                 /course/the-complete-sql-bootcamp/     True
# 1                                 /course/tableau10/     True
# 2                        /course/pmp-pmbok6-35-pdus/     True
# 3     /course/the-complete-financial-analyst-course/     True
# 4  /course/an-entire-mba-in-1-courseaward-winning...     True
#
#    num_subscribers  avg_rating  avg_rating_recent   rating  num_reviews  \
# 0           295509     4.66019            4.67874  4.67874        78006
# 1           209070     4.58956            4.60015  4.60015        54581
# 2           155282     4.59491            4.59326  4.59326        52653
# 3           245860     4.54407            4.53772  4.53772        46447
# 4           374836     4.47080            4.47173  4.47173        41630
#
#    is_wishlisted  num_published_lectures  num_published_practice_tests  \
# 0          False                      84                             0
# 1          False                      78                             0
# 2          False                     292                             2
# 3          False                     338                             0
# 4          False                      83                             0
#
#                 created        published_time  discount_price__amount  \
# 0  2016-02-14T22:57:48Z  2016-04-06T05:16:11Z                   455.0
# 1  2016-08-22T12:10:18Z  2016-08-23T16:59:49Z                   455.0
# 2  2017-09-26T16:32:48Z  2017-11-14T23:58:14Z                   455.0
# 3  2015-10-23T13:34:35Z  2016-01-21T01:38:48Z                   455.0
# 4  2015-10-12T06:39:46Z  2016-01-11T21:39:33Z                   455.0
#
#   discount_price__currency discount_price__price_string  price_detail__amount  \
# 0                      INR                         ₹455                  8640
# 1                      INR                         ₹455                  8640
# 2                      INR                         ₹455                  8640
# 3                      INR                         ₹455                  8640
# 4                      INR                         ₹455                  8640
#
#   price_detail__currency price_detail__price_string
# 0                    INR                     ₹8,640
# 1                    INR                     ₹8,640
# 2                    INR                     ₹8,640
# 3                    INR                     ₹8,640
# 4                    INR                     ₹8,640

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9447 entries, 0 to 9446
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            9447 non-null   int64
#  1   title                         9447 non-null   object
#  2   url                           9447 non-null   object
#  3   is_paid                       9447 non-null   bool
#  4   num_subscribers               9447 non-null   int64
#  5   avg_rating                    9447 non-null   float64
#  6   avg_rating_recent             9447 non-null   float64
#  7   rating                        9447 non-null   float64
#  8   num_reviews                   9447 non-null   int64
#  9   is_wishlisted                 9447 non-null   bool
#  10  num_published_lectures        9447 non-null   int64
#  11  num_published_practice_tests  9447 non-null   int64
#  12  created                       9447 non-null   object
#  13  published_time                9447 non-null   object
#  14  discount_price__amount        8937 non-null   float64
#  15  discount_price__currency      8937 non-null   object
#  16  discount_price__price_string  8937 non-null   object
#  17  price_detail__amount          9447 non-null   int64
#  18  price_detail__currency        9447 non-null   object
#  19  price_detail__price_string    9447 non-null   object
# dtypes: bool(2), float64(4), int64(6), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# #### Data Cleaning

# %%
data.shape
# Out:
# (9447, 20)

# %%
data.isnull().sum()
# Out:
# id                                0
# title                             0
# url                               0
# is_paid                           0
# num_subscribers                   0
# avg_rating                        0
# avg_rating_recent                 0
# rating                            0
# num_reviews                       0
# is_wishlisted                     0
# num_published_lectures            0
# num_published_practice_tests      0
# created                           0
# published_time                    0
# discount_price__amount          510
# discount_price__currency        510
# discount_price__price_string    510
# price_detail__amount              0
# price_detail__currency            0
# price_detail__price_string        0
# dtype: int64

# %% [markdown]
# The are total of 510 discount given out of 9447.

# %%
data['discount_price__currency'].nunique()
# Out:
# 1

# %% [markdown]
# There are only one type of currency so we can drop two collumns :
# - discount_price__price_string
# - price_detail__price_string
#
# These two are duplicate and string format.

# %%
data.drop(['discount_price__price_string','price_detail__price_string'],axis = 1,inplace= True)

# %%
data.drop(['url', 'discount_price__currency','price_detail__currency'], axis=1, inplace=True)

# %% [markdown]
# We can also remove url and currency as all are in IND.

# %%
data['id'].nunique()
# Out:
# 9447

# %% [markdown]
# We can say that all the id are unique

# %%
data.drop('rating',axis = 1, inplace = True)

# %% [markdown]
# We removed rating as
# - Rating and Average Recent Rating are the same columns'

# %%
data.isna().sum()
# Out:
# id                                0
# title                             0
# is_paid                           0
# num_subscribers                   0
# avg_rating                        0
# avg_rating_recent                 0
# num_reviews                       0
# is_wishlisted                     0
# num_published_lectures            0
# num_published_practice_tests      0
# created                           0
# published_time                    0
# discount_price__amount          510
# price_detail__amount              0
# dtype: int64

# %%
data.fillna(0,inplace= True)

# %%
data.isna().sum()
# Out:
# id                              0
# title                           0
# is_paid                         0
# num_subscribers                 0
# avg_rating                      0
# avg_rating_recent               0
# num_reviews                     0
# is_wishlisted                   0
# num_published_lectures          0
# num_published_practice_tests    0
# created                         0
# published_time                  0
# discount_price__amount          0
# price_detail__amount            0
# dtype: int64

# %% [markdown]
# #### Date

# %%
data['created'] = pd.to_datetime(data['created'])
data['published_time'] = pd.to_datetime(data['published_time'])
data['Year']  = data['published_time'].dt.year

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9447 entries, 0 to 9446
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            9447 non-null   int64
#  1   title                         9447 non-null   object
#  2   is_paid                       9447 non-null   bool
#  3   num_subscribers               9447 non-null   int64
#  4   avg_rating                    9447 non-null   float64
#  5   avg_rating_recent             9447 non-null   float64
#  6   num_reviews                   9447 non-null   int64
#  7   is_wishlisted                 9447 non-null   bool
#  8   num_published_lectures        9447 non-null   int64
#  9   num_published_practice_tests  9447 non-null   int64
#  10  created                       9447 non-null   datetime64[ns, UTC]
#  11  published_time                9447 non-null   datetime64[ns, UTC]
#  12  discount_price__amount        9447 non-null   float64
#  13  price_detail__amount          9447 non-null   int64
#  14  Year                          9447 non-null   int64
# dtypes: bool(2), datetime64[ns, UTC](2), float64(3), int64(7), object(1)
# memory usage: 978.0+ KB

# %%
data['diff_published_and_creation'] = data['published_time'] - data['created']

# %%
data['diff_published_and_creation'] = (data['published_time'] - data['created']).dt.total_seconds() / 60

# %% [markdown]
# Convert the difference between date in to minutes

# %%
data.loc[(data['diff_published_and_creation'] < 0)]
# Out:
#        id                                              title  is_paid  \
# 686  2762  Simple Strategy for Swing Trading the Stock Ma...     True
#
#      num_subscribers  avg_rating  avg_rating_recent  num_reviews  \
# 686             2268     4.21642            4.22936          674
#
#      is_wishlisted  num_published_lectures  num_published_practice_tests  \
# 686          False                       8                             0
#
#                       created            published_time  \
# 686 2010-04-14 21:32:46+00:00 2010-04-14 16:32:46+00:00
#
#      discount_price__amount  price_detail__amount  Year  \
# 686                   468.0                  2560  2010
#
#      diff_published_and_creation
# 686                       -300.0

# %% [markdown]
# we can see that there is one data whose date diff is negative so we have to drop the value.

# %%
data.drop(data[data['diff_published_and_creation'] < 0].index,inplace= True)

# %%
data.drop('diff_published_and_creation',axis=1,inplace=True)

# %%
data['created']  = pd.to_datetime(data['created'].to_list()).strftime('%m/%d/%Y').values
data['published_time']  = pd.to_datetime(data['published_time'].to_list()).strftime('%m/%d/%Y').values
data.head()
# Out:
#         id                                              title  is_paid  \
# 0   762616  The Complete SQL Bootcamp 2020: Go from Zero t...     True
# 1   937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...     True
# 2  1361790             PMP Exam Prep Seminar -  PMBOK Guide 6     True
# 3   648826         The Complete Financial Analyst Course 2020     True
# 4   637930  An Entire MBA in 1 Course:Award Winning Busine...     True
#
#    num_subscribers  avg_rating  avg_rating_recent  num_reviews  is_wishlisted  \
# 0           295509     4.66019            4.67874        78006          False
# 1           209070     4.58956            4.60015        54581          False
# 2           155282     4.59491            4.59326        52653          False
# 3           245860     4.54407            4.53772        46447          False
# 4           374836     4.47080            4.47173        41630          False
#
#    num_published_lectures  num_published_practice_tests     created  \
# 0                      84                             0  02/14/2016
# 1                      78                             0  08/22/2016
# 2                     292                             2  09/26/2017
# 3                     338                             0  10/23/2015
# 4                      83                             0  10/12/2015
#
#   published_time  discount_price__amount  price_detail__amount  Year
# 0     04/06/2016                   455.0                  8640  2016
# 1     08/23/2016                   455.0                  8640  2016
# 2     11/14/2017                   455.0                  8640  2017
# 3     01/21/2016                   455.0                  8640  2016
# 4     01/11/2016                   455.0                  8640  2016

# %% [markdown]
# #### EDA

# %%
sns.boxplot(x =data['avg_rating'] )
# Out:
# <AxesSubplot:xlabel='avg_rating'>

# %%
(data[data['avg_rating'] < 3]).count()
# Out:
# id                              177
# title                           177
# is_paid                         177
# num_subscribers                 177
# avg_rating                      177
# avg_rating_recent               177
# num_reviews                     177
# is_wishlisted                   177
# num_published_lectures          177
# num_published_practice_tests    177
# created                         177
# published_time                  177
# discount_price__amount          177
# price_detail__amount            177
# Year                            177
# dtype: int64

# %%
data.drop(data[data['avg_rating'] < 3].index,inplace= True)

# %%
data.shape
# Out:
# (9269, 15)

# %%
data['rating_binned'] = pd.cut(data['avg_rating_recent'], [0,1,2,3,4,5])

# %%
sns.barplot(x = data['rating_binned'] , y = data['num_subscribers'])
# Out:
# <AxesSubplot:xlabel='rating_binned', ylabel='num_subscribers'>

# %%
sns.barplot(x = data['rating_binned'] , y = data['num_reviews'])
# Out:
# <AxesSubplot:xlabel='rating_binned', ylabel='num_reviews'>

# %%
sns.barplot(x = data['rating_binned'] , y = data['price_detail__amount'])
# Out:
# <AxesSubplot:xlabel='rating_binned', ylabel='price_detail__amount'>

# %%
sns.barplot(x = data['rating_binned'] , y = data['discount_price__amount'])
# Out:
# <AxesSubplot:xlabel='rating_binned', ylabel='discount_price__amount'>

# %% [markdown]
# - We have the Highest number of subscribers for rating between 4 to 5.
# - which is also have highest review. We can see that people tends to rievew less to those with less rating.

# %%
correlated_data = ['num_subscribers', 'avg_rating_recent', 'num_reviews','num_published_lectures', 'price_detail__amount','discount_price__amount','num_published_practice_tests']

# %%
sns.heatmap(data[correlated_data].corr(),annot=True,cmap=sns.diverging_palette(20, 220, as_cmap=True),vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - The is a relation between {Number of Subscribers} and {Number of Reviews},which is the strongest of all.
# - num_published_lectures/price_detail_amount - it shows a tendency of increasing prices as the the courses lenght increase
# - num_subscribers and num_published_lectures is third highest relation.

# %%
sns.regplot(x='num_subscribers', y='num_reviews', data=data, marker=',')
# Out:
# <AxesSubplot:xlabel='num_subscribers', ylabel='num_reviews'>

# %%
sns.regplot(x='num_published_lectures', y='price_detail__amount', data=data,marker=',', color='teal')
# Out:
# <AxesSubplot:xlabel='num_published_lectures', ylabel='price_detail__amount'>

# %%
sns.regplot(x='num_subscribers', y='num_published_lectures', data=data, marker=',', scatter_kws={"color": "black"}, line_kws={"color": "red"})
# Out:
# <AxesSubplot:xlabel='num_subscribers', ylabel='num_published_lectures'>

# %%
data['is_paid'].nunique()
# Out:
# 1

# %%
data['is_wishlisted'].nunique()
# Out:
# 1

# %% [markdown]
# - There is only Paid courses in the data.
# - None of the courses were in wishlist.

# %%
detail_per_year = data.groupby('Year').agg({'num_subscribers':np.sum,'num_reviews':np.sum,'num_published_lectures':np.sum,'price_detail__amount':np.mean,"discount_price__amount":np.mean}).reset_index()
detail_per_year
# Out:
#    Year  num_subscribers  num_reviews  num_published_lectures  \
# 0  2011            25558         1538                     375
# 1  2012           112534         7493                    1844
# 2  2013          1125014       109286                    9038
# 3  2014          2535028       216911                   21637
# 4  2015          4755391       423724                   44411
# 5  2016          5888801       700476                   37865
# 6  2017          5740863       719934                   46591
# 7  2018          5096805       406263                   70118
# 8  2019          3230398       173739                   51581
# 9  2020          3158116        57860                   37530
#
#    price_detail__amount  discount_price__amount
# 0           3520.000000              460.000000
# 1           3190.000000              439.062500
# 2           3800.131148              388.481967
# 3           4043.250415              421.036484
# 4           4467.027027              443.872019
# 5           4825.612053              457.759887
# 6           5126.360521              464.572995
# 7           5196.634304              471.975189
# 8           5135.088409              476.273739
# 9           4717.730496              496.129433

# %%
fig, ax = plt.subplots(1,2,figsize=(20,6))
sns.lineplot(x = 'Year',y = 'num_subscribers',data = detail_per_year,ax=ax[0])
ax[0].set_title('Sum of Subscribers')
sns.lineplot(x = 'Year',y = 'num_reviews',data = detail_per_year,ax=ax[1])
ax[1].set_title('Sum of Reviews')
# Out:
# Text(0.5, 1.0, 'Sum of Reviews')

# %% [markdown]
# - There is a consistant rise in subscribers and reviews from 2012 to 2016. The
# subscribers and reviews are positively correlated.
# - After 2016 onwards there is a decrease in subscribers and reviews.

# %%
fig, ax = plt.subplots(1,3,figsize=(20,6))
sns.lineplot(x = 'Year',y = 'discount_price__amount',data = detail_per_year,ax=ax[0])
ax[0].set_title('Mean Discount')
sns.lineplot(x = 'Year',y = 'price_detail__amount',data = detail_per_year,ax=ax[1])
ax[1].set_title('Mean Price')
sns.lineplot(x = 'Year',y = 'num_published_lectures',data = detail_per_year,ax=ax[2])
ax[2].set_title('Total Lectures')
# Out:
# Text(0.5, 1.0, 'Total Lectures')

# %% [markdown]
# - As the Average Price increases the Lectures also increase with the years till 2018.
# - After 2018 there is a decrease in Average Price and the lectures, but there is a increase in average discount after 2018.

# %%
data[['title', 'num_subscribers', 'avg_rating','avg_rating_recent']].sort_values(by="num_subscribers", ascending=False).set_index('title')[:15]
# Out:
#                                                     num_subscribers  \
# title
# An Entire MBA in 1 Course:Award Winning Busines...           374836
# The Complete SQL Bootcamp 2020: Go from Zero to...           295509
# The Complete Financial Analyst Course 2020                   245860
# Deep Learning Prerequisites: The Numpy Stack in...           239309
# Tableau 2020 A-Z: Hands-On Tableau Training for...           209070
# The Complete Financial Analyst Training & Inves...           182002
# The Complete Presentation and Public Speaking/S...           158654
# PMP Exam Prep Seminar -  PMBOK Guide 6                       155282
# Introduction to Finance, Accounting, Modeling a...           140676
# Beginner to Pro in Excel: Financial Modeling an...           127680
# Microsoft Power BI - A Complete Introduction [2...           124180
# The Business Intelligence Analyst Course 2020                115269
# The Ultimate Hands-On Hadoop - Tame your Big Data!           114945
# Become a Product Manager | Learn the Skills & G...           112572
# Writing With Flair: How To Become An Exceptiona...           102727
#
#                                                     avg_rating  \
# title
# An Entire MBA in 1 Course:Award Winning Busines...     4.47080
# The Complete SQL Bootcamp 2020: Go from Zero to...     4.66019
# The Complete Financial Analyst Course 2020             4.54407
# Deep Learning Prerequisites: The Numpy Stack in...     4.47381
# Tableau 2020 A-Z: Hands-On Tableau Training for...     4.58956
# The Complete Financial Analyst Training & Inves...     4.49571
# The Complete Presentation and Public Speaking/S...     4.46745
# PMP Exam Prep Seminar -  PMBOK Guide 6                 4.59491
# Introduction to Finance, Accounting, Modeling a...     4.47580
# Beginner to Pro in Excel: Financial Modeling an...     4.54034
# Microsoft Power BI - A Complete Introduction [2...     4.56228
# The Business Intelligence Analyst Course 2020          4.50067
# The Ultimate Hands-On Hadoop - Tame your Big Data!     4.51251
# Become a Product Manager | Learn the Skills & G...     4.50386
# Writing With Flair: How To Become An Exceptiona...     4.55248
#
#                                                     avg_rating_recent
# title
# An Entire MBA in 1 Course:Award Winning Busines...            4.47173
# The Complete SQL Bootcamp 2020: Go from Zero to...            4.67874
# The Complete Financial Analyst Course 2020                    4.53772
# Deep Learning Prerequisites: The Numpy Stack in...            4.54005
# Tableau 2020 A-Z: Hands-On Tableau Training for...            4.60015
# The Complete Financial Analyst Training & Inves...            4.49507
# The Complete Presentation and Public Speaking/S...            4.44446
# PMP Exam Prep Seminar -  PMBOK Guide 6                        4.59326
# Introduction to Finance, Accounting, Modeling a...            4.46916
# Beginner to Pro in Excel: Financial Modeling an...            4.53346
# Microsoft Power BI - A Complete Introduction [2...            4.57676
# The Business Intelligence Analyst Course 2020                 4.49575
# The Ultimate Hands-On Hadoop - Tame your Big Data!            4.52998
# Become a Product Manager | Learn the Skills & G...            4.50080
# Writing With Flair: How To Become An Exceptiona...            4.56591

# %%
data['rating_diff'] = data['avg_rating_recent'] - data['avg_rating']
data
# Out:
#            id                                              title  is_paid  \
# 0      762616  The Complete SQL Bootcamp 2020: Go from Zero t...     True
# 1      937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...     True
# 2     1361790             PMP Exam Prep Seminar -  PMBOK Guide 6     True
# 3      648826         The Complete Financial Analyst Course 2020     True
# 4      637930  An Entire MBA in 1 Course:Award Winning Busine...     True
# ...       ...                                                ...      ...
# 9441  2378286                         Ten Steps to Sales Success     True
# 9442  1934910   Simple Value Investing Guide With Proven Methods     True
# 9444  1964000  Leadership Development:Ready To Use Tools to l...     True
# 9445  2769588  Business Efficiency: How To Increase Workplace...     True
# 9446  2801192                        How to enter the US market?     True
#
#       num_subscribers  avg_rating  avg_rating_recent  num_reviews  \
# 0              295509     4.66019            4.67874        78006
# 1              209070     4.58956            4.60015        54581
# 2              155282     4.59491            4.59326        52653
# 3              245860     4.54407            4.53772        46447
# 4              374836     4.47080            4.47173        41630
# ...               ...         ...                ...          ...
# 9441               19     4.33333            4.49935            3
# 9442             1129     3.50000            3.43520            3
# 9444             1017     4.16667            3.88844            3
# 9445             1716     3.66667            3.52632            3
# 9446               14     5.00000            5.00000            3
#
#       is_wishlisted  num_published_lectures  num_published_practice_tests  \
# 0             False                      84                             0
# 1             False                      78                             0
# 2             False                     292                             2
# 3             False                     338                             0
# 4             False                      83                             0
# ...             ...                     ...                           ...
# 9441          False                      12                             0
# 9442          False                      35                             0
# 9444          False                       5                             0
# 9445          False                       7                             0
# 9446          False                       5                             0
#
#          created published_time  discount_price__amount  price_detail__amount  \
# 0     02/14/2016     04/06/2016                   455.0                  8640
# 1     08/22/2016     08/23/2016                   455.0                  8640
# 2     09/26/2017     11/14/2017                   455.0                  8640
# 3     10/23/2015     01/21/2016                   455.0                  8640
# 4     10/12/2015     01/11/2016                   455.0                  8640
# ...          ...            ...                     ...                   ...
# 9441  05/21/2019     08/06/2019                   455.0                  1600
# 9442  09/27/2018     10/31/2018                   455.0                  8640
# 9444  10/13/2018     10/27/2018                   455.0                  6400
# 9445  01/20/2020     01/21/2020                   455.0                  6400
# 9446  02/07/2020     02/11/2020                   455.0                  6400
#
#       Year rating_binned  rating_diff
# 0     2016        (4, 5]      0.01855
# 1     2016        (4, 5]      0.01059
# 2     2017        (4, 5]     -0.00165
# 3     2016        (4, 5]     -0.00635
# 4     2016        (4, 5]      0.00093
# ...    ...           ...          ...
# 9441  2019        (4, 5]      0.16602
# 9442  2018        (3, 4]     -0.06480
# 9444  2018        (3, 4]     -0.27823
# 9445  2020        (3, 4]     -0.14035
# 9446  2020        (4, 5]      0.00000
#
# [9269 rows x 17 columns]

# %%
	
new = data.drop('Year',axis = 1)
new
# Out:
#            id                                              title  is_paid  \
# 0      762616  The Complete SQL Bootcamp 2020: Go from Zero t...     True
# 1      937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...     True
# 2     1361790             PMP Exam Prep Seminar -  PMBOK Guide 6     True
# 3      648826         The Complete Financial Analyst Course 2020     True
# 4      637930  An Entire MBA in 1 Course:Award Winning Busine...     True
# ...       ...                                                ...      ...
# 9441  2378286                         Ten Steps to Sales Success     True
# 9442  1934910   Simple Value Investing Guide With Proven Methods     True
# 9444  1964000  Leadership Development:Ready To Use Tools to l...     True
# 9445  2769588  Business Efficiency: How To Increase Workplace...     True
# 9446  2801192                        How to enter the US market?     True
#
#       num_subscribers  avg_rating  avg_rating_recent  num_reviews  \
# 0              295509     4.66019            4.67874        78006
# 1              209070     4.58956            4.60015        54581
# 2              155282     4.59491            4.59326        52653
# 3              245860     4.54407            4.53772        46447
# 4              374836     4.47080            4.47173        41630
# ...               ...         ...                ...          ...
# 9441               19     4.33333            4.49935            3
# 9442             1129     3.50000            3.43520            3
# 9444             1017     4.16667            3.88844            3
# 9445             1716     3.66667            3.52632            3
# 9446               14     5.00000            5.00000            3
#
#       is_wishlisted  num_published_lectures  num_published_practice_tests  \
# 0             False                      84                             0
# 1             False                      78                             0
# 2             False                     292                             2
# 3             False                     338                             0
# 4             False                      83                             0
# ...             ...                     ...                           ...
# 9441          False                      12                             0
# 9442          False                      35                             0
# 9444          False                       5                             0
# 9445          False                       7                             0
# 9446          False                       5                             0
#
#          created published_time  discount_price__amount  price_detail__amount  \
# 0     02/14/2016     04/06/2016                   455.0                  8640
# 1     08/22/2016     08/23/2016                   455.0                  8640
# 2     09/26/2017     11/14/2017                   455.0                  8640
# 3     10/23/2015     01/21/2016                   455.0                  8640
# 4     10/12/2015     01/11/2016                   455.0                  8640
# ...          ...            ...                     ...                   ...
# 9441  05/21/2019     08/06/2019                   455.0                  1600
# 9442  09/27/2018     10/31/2018                   455.0                  8640
# 9444  10/13/2018     10/27/2018                   455.0                  6400
# 9445  01/20/2020     01/21/2020                   455.0                  6400
# 9446  02/07/2020     02/11/2020                   455.0                  6400
#
#      rating_binned  rating_diff
# 0           (4, 5]      0.01855
# 1           (4, 5]      0.01059
# 2           (4, 5]     -0.00165
# 3           (4, 5]     -0.00635
# 4           (4, 5]      0.00093
# ...            ...          ...
# 9441        (4, 5]      0.16602
# 9442        (3, 4]     -0.06480
# 9444        (3, 4]     -0.27823
# 9445        (3, 4]     -0.14035
# 9446        (4, 5]      0.00000
#
# [9269 rows x 16 columns]

# %%
new.to_excel('file.xlsx')
new.to_csv('new.csv')

# %%
sub = data[['title', 'num_subscribers', 'avg_rating','avg_rating_recent','rating_diff','num_published_lectures','price_detail__amount']].sort_values(by="num_subscribers", ascending=False).reset_index()[:20]
sub
# Out:
#     index                                              title  num_subscribers  \
# 0       4  An Entire MBA in 1 Course:Award Winning Busine...           374836
# 1       0  The Complete SQL Bootcamp 2020: Go from Zero t...           295509
# 2       3         The Complete Financial Analyst Course 2020           245860
# 3      19  Deep Learning Prerequisites: The Numpy Stack i...           239309
# 4       1  Tableau 2020 A-Z: Hands-On Tableau Training fo...           209070
# 5      15  The Complete Financial Analyst Training & Inve...           182002
# 6      35  The Complete Presentation and Public Speaking/...           158654
# 7       2             PMP Exam Prep Seminar -  PMBOK Guide 6           155282
# 8      22  Introduction to Finance, Accounting, Modeling ...           140676
# 9       7  Beginner to Pro in Excel: Financial Modeling a...           127680
# 10      5  Microsoft Power BI - A Complete Introduction [...           124180
# 11      9      The Business Intelligence Analyst Course 2020           115269
# 12     16  The Ultimate Hands-On Hadoop - Tame your Big D...           114945
# 13      8  Become a Product Manager | Learn the Skills & ...           112572
# 14     26  Writing With Flair: How To Become An Exception...           102727
# 15      6  Agile Crash Course: Agile Project Management; ...            96207
# 16    208          Work From Home: The Amazon FBA MasterPlan            93749
# 17    607  Business Bootcamp: 7 Weeks to Start Your Own B...            89171
# 18     17        The Complete Investment Banking Course 2020            88468
# 19     77  The Complete Personal Finance Course: Save,Pro...            87181
#
#     avg_rating  avg_rating_recent  rating_diff  num_published_lectures  \
# 0      4.47080            4.47173      0.00093                      83
# 1      4.66019            4.67874      0.01855                      84
# 2      4.54407            4.53772     -0.00635                     338
# 3      4.47381            4.54005      0.06624                      47
# 4      4.58956            4.60015      0.01059                      78
# 5      4.49571            4.49507     -0.00064                     225
# 6      4.46745            4.44446     -0.02299                     206
# 7      4.59491            4.59326     -0.00165                     292
# 8      4.47580            4.46916     -0.00664                      61
# 9      4.54034            4.53346     -0.00688                     275
# 10     4.56228            4.57676      0.01448                     275
# 11     4.50067            4.49575     -0.00492                     413
# 12     4.51251            4.52998      0.01747                     101
# 13     4.50386            4.50080     -0.00306                     144
# 14     4.55248            4.56591      0.01343                      78
# 15     4.32383            4.29118     -0.03265                      23
# 16     4.17778            3.99013     -0.18765                      41
# 17     4.50943            4.42418     -0.08525                      51
# 18     4.49804            4.48929     -0.00875                     160
# 19     4.54567            4.58665      0.04098                     122
#
#     price_detail__amount
# 0                   8640
# 1                   8640
# 2                   8640
# 3                   1280
# 4                   8640
# 5                   8640
# 6                  10240
# 7                   8640
# 8                   9280
# 9                   8640
# 10                  8640
# 11                  8640
# 12                  8640
# 13                  8640
# 14                  8640
# 15                  8640
# 16                  6080
# 17                  8640
# 18                  8640
# 19                  8640

# %%
plt.figure(figsize=(6,15))
sns.barplot(x="num_subscribers",y ="title",data = sub)
plt.title('Top 20 Courses with most subscribed')
plt.show()

# %%
plt.figure(figsize=(6,15))
sns.barplot(x="num_published_lectures",y ="title",data = sub)
plt.title('Top 20 Courses with most subscribed')
plt.show()

# %% [markdown]
# - We can see that the highest subscribed course is related to Financial{An Entire MBA in 1 Course:Award Winning Business School} but it doesnot have the max number of lectures {83}.
# - The max number of lectures to the course {The Business Intelligence Analyst Course 2020} which is 12th in the subscription rank and 2nd higest number lecture is in 3rd rak of subscription {The Complete Financial Analyst Course 2020}.
# - Most of the subscribed courses in top 20 belong to Financial and Data Science Category.

# %%
plt.figure(figsize=(6,15))
sns.barplot(x="avg_rating_recent",y ="title",data = sub)
plt.title('Top 20 Courses with most subscribed')
plt.show()

# %%
plt.figure(figsize=(6,15))
sns.barplot(x="rating_diff",y ="title",data = sub)
plt.title('Top 20 Courses with most subscribed')
plt.show()

# %% [markdown]
# - We can see that some of the ratings of courses have decrease.

# %%
data[['title', 'num_subscribers','published_time']].sort_values(by='published_time')
# Out:
#                                                   title  num_subscribers  \
# 2563  Start a Business and Travel the World in 30 Days!            11547
# 5256  How to Succeed in Business Without a College D...             1014
# 311   Professional Life Coaching Certification PCELC...             9048
# 704   Certification Stress Management Coaching CGRSC...             5375
# 2496                   FOREX : Learn Technical Analysis             1691
# ...                                                 ...              ...
# 2217                          First Time Manager Course             2272
# 8423                    Convincing Clients in 5 Minutes              672
# 5994  Luxury Travel Advisor | The Ultimate Lifestyle...               67
# 1580        Forensic Accounting and Fraud Investigation              472
# 9119  Kindle Direct Publishing Self Publishing Low C...              123
#
#      published_time
# 2563     01/01/2015
# 5256     01/01/2015
# 311      01/01/2016
# 704      01/01/2016
# 2496     01/01/2016
# ...             ...
# 2217     12/31/2019
# 8423     12/31/2019
# 5994     12/31/2019
# 1580     12/31/2019
# 9119     12/31/2019
#
# [9269 rows x 3 columns]

# %%
data[['title', 'num_subscribers','published_time']].sort_values(by='published_time',ascending = False)
# Out:
#                                                   title  num_subscribers  \
# 9119  Kindle Direct Publishing Self Publishing Low C...              123
# 2217                          First Time Manager Course             2272
# 5994  Luxury Travel Advisor | The Ultimate Lifestyle...               67
# 1580        Forensic Accounting and Fraud Investigation              472
# 8423                    Convincing Clients in 5 Minutes              672
# ...                                                 ...              ...
# 311   Professional Life Coaching Certification PCELC...             9048
# 1240  How to Use Upwork to Make a Living: Freelance ...             6376
# 921   Confidence Coaching Certification CGRCC Confid...             3569
# 5256  How to Succeed in Business Without a College D...             1014
# 2563  Start a Business and Travel the World in 30 Days!            11547
#
#      published_time
# 9119     12/31/2019
# 2217     12/31/2019
# 5994     12/31/2019
# 1580     12/31/2019
# 8423     12/31/2019
# ...             ...
# 311      01/01/2016
# 1240     01/01/2016
# 921      01/01/2016
# 5256     01/01/2015
# 2563     01/01/2015
#
# [9269 rows x 3 columns]

# %%
data['title'].duplicated().sum()
# Out:
# 21

# %% [markdown]
# - By comparing above two tabel we can say that publist date doesnot garenty quality of lectures.
